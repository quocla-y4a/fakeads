# %%
pip install underthesea
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.3 MB 9.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.3 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.3 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.3 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 10.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/722.6 kB ? eta -:--:--
#    ---------------------------------------- 722.6/722.6 kB 9.8 MB/s  0:00:00
# ...
#
#    -------------------------- ------------- 2/3 [underthesea]
#    -------------------------- ------------- 2/3 [underthesea]
#    -------------------------- ------------- 2/3 [underthesea]
#    -------------------------- ------------- 2/3 [underthesea]
#    -------------------------- ------------- 2/3 [underthesea]
#    -------------------------- ------------- 2/3 [underthesea]
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import underthesea

# %% [markdown]
# ### Get data

# %%
data  = pd.read_csv('data/2025-10-21/video_data.csv')

# %%
data.head()
# Out:
#       video_id                                              title  \
# 0  bPsAKX1ocTs  Mỗi ngày Yakult – Mỗi ngày khỏe mạnh | TVC Yakult
#
#                                          description           publishedAt  \
# 0  Mỗi ngày Yakult – Mỗi ngày khỏe mạnh\nNăm 1935...  2023-07-01T02:00:17Z
#
#                   channelId     channelTitle tags  viewCount  likeCount  \
# 0  UCH8rxDxaR7MhuZAlF4CC91Q  Yakult Việt Nam   []    2271929        NaN
#
#    commentCount duration  caption               transcript
# 0            63    PT30S    False  No transcript available

# %%
df = data.copy()

# %% [markdown]
# ## Preprocessing

# %%
df['Title'] =
