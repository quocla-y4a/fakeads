# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import underthesea

# %% [markdown]
# ## Get data

# %%
data  = pd.read_csv('merged_data/2025-11-07/job_data.csv')

# %%
data.head()
# Out:
#     job_id                                          job_title company  \
# 0  1932289   IT Camera Support (Thu Nhập Upto 11 Triệu/Tháng)     NaN
# 1  1781998  Mobile Developer  Kotlin - Junior Level (Andro...     NaN
# 2  1418016        Lập Trình Viên Backend (Java Middle/Senior)  FPT IS
# 3  1943602                             Kỹ Sư Trí Tuệ Nhân Tạo     NaN
# 4  1942161                               Mobile Game Designer     NaN
#
#    salary_min  salary_max  yrs_of_exp_min  yrs_of_exp_max  \
# 0         9.0        11.0             1.0             1.0
# 1         NaN         NaN             1.0             1.0
# 2         NaN         NaN             2.0             2.0
# 3         NaN         NaN             2.0             2.0
# 4         NaN         NaN             1.0             1.0
#
#               job_city due_date  \
# 0             Hưng Yên      NaN
# 1               Hà Nội      NaN
# 2               Hà Nội      NaN
# 3  Hà Nội, Hồ Chí Minh      NaN
# ...

# %%
df = data.copy()

# %%
print("\n--- BASIC DATA INFO ---")
print(df.info())
print("\n--- MISSING VALUES ---")
print(df.isna().sum())
print("\n--- BASIC STATS (Salary) ---")
print(df.describe())
print("\n--- TOP COMPANIES ---")
print(df["company_name"].value_counts().head(10))
print("\n--- TOP JOB TITLES ---")
print(df["job_title"].value_counts().head(10))
# Out:
# --- BASIC DATA INFO ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1526 entries, 0 to 1525
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   job_id          1526 non-null   int64
#  1   job_title       1526 non-null   object
#  2   company         79 non-null     object
#  3   salary_min      639 non-null    float64
#  4   salary_max      809 non-null    float64
#  5   yrs_of_exp_min  1243 non-null   float64
#  6   yrs_of_exp_max  1278 non-null   float64
#  7   job_city        1443 non-null   object
#  8   due_date        43 non-null     object
#  9   jd              1412 non-null   object
#  10  job_url         1526 non-null   object
#  11  salary_text     1526 non-null   object
#  12  company_name    1526 non-null   object
#  13  company_link    1526 non-null   object
#  14  updated_at      1526 non-null   object
#  15  time_left       1526 non-null   object
# ...

# %%
data.describe()
# Out:
#              job_id     salary_min     salary_max  yrs_of_exp_min  \
# count  1.526000e+03     639.000000     809.000000     1243.000000
# mean   1.811290e+06     752.566510     835.365884        2.436042
# std    2.518269e+05   18575.757527   22929.108938        1.194346
# min    7.406300e+04       1.000000       1.000000        1.000000
# 25%    1.819168e+06      10.500000      18.000000        2.000000
# 50%    1.915502e+06      15.000000      26.000000        2.000000
# 75%    1.931736e+06      20.000000      36.000000        3.000000
# max    1.943985e+06  469584.000000  652200.000000        5.000000
#
#        yrs_of_exp_max
# count     1278.000000
# mean         2.255869
# std          1.119112
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          5.000000
